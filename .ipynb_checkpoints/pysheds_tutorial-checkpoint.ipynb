# %%
# You only need to run this the first time you run the notebook.
# pip install pysheds

# %%
# pip install seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from pysheds.grid import Grid
# %matplotlib inline

# %%
# Read elevation and flow direction rasters
# ----------------------------
from pysheds.grid import Grid

# %%
grid = Grid.from_raster('data/n30w100_con_grid/n30w100_con/n30w100_con', data_name='dem')

# %%
fig, ax = plt.subplots(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(grid.dem, extent=grid.extent, cmap='cubehelix', zorder=1)
plt.colorbar(label='Elevation (m)')
plt.grid(zorder=0)
plt.title('Digital elevation map')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.tight_layout()
plt.savefig('img/conditioned_dem.png', bbox_inches='tight')

# %%
grid.resolve_flats('dem', out_name='inflated_dem')

# %%
#N    NE    E    SE    S    SW    W    NW
dirmap = (64,  128,  1,   2,    4,   8,    16,  32)

# %%
grid.flowdir(data='inflated_dem', out_name='dir', dirmap=dirmap)

# %%
fig = plt.figure(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(grid.dir, extent=grid.extent, cmap='viridis', zorder=2)
boundaries = ([0] + sorted(list(dirmap)))
plt.colorbar(boundaries= boundaries,
             values=sorted(dirmap))
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Flow direction grid')
plt.grid(zorder=-1)
plt.tight_layout()
plt.savefig('img/flow_direction.png', bbox_inches='tight')

# %%
grid.read_raster('data/n30w100_dir_grid/n30w100_dir/n30w100_dir', data_name='dir')

# %%
grid.dir
# Out:
# Raster([[ 64,  64,  64, ...,   1,   2, 128],
#         [ 32,  64,  64, ...,   1,   1, 128],
#         [ 32,  32,  32, ...,   1, 128,  64],
#         ...,
#         [128,  64,  64, ...,  16,   8,   4],
#         [128,  64,  64, ...,   4,  16,   4],
#         [  8,  64,  64, ...,   8,   4,   4]], dtype=uint8)

# %%
grid.dir.size
# Out:
# 36000000

# %%
fig = plt.figure(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(grid.dir, extent=grid.extent, cmap='viridis', zorder=2)
boundaries = ([0] + sorted(list(dirmap)))
plt.colorbar(boundaries= boundaries,
             values=sorted(dirmap))
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Flow direction grid')
plt.grid(zorder=-1)
plt.tight_layout()

# %%
# Specify pour point
# x, y = -97.293, 32.736
x, y = -97.293, 32.736

# Delineate the catchment
grid.catchment(data='dir', x=x, y=y, dirmap=dirmap, out_name='catch',
               recursionlimit=15000, xytype='label', nodata_out=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-3b821b2f59a2> in <module>
#       5 # Delineate the catchment
#       6 grid.catchment(data='dir', x=x, y=y, dirmap=dirmap, out_name='catch',
# ----> 7                recursionlimit=15000, xytype='label', nodata_out=0)
#
# ~/.local/lib/python3.6/site-packages/pysheds/grid.py in catchment(self, x, y, data, pour_value, out_name, dirmap, nodata_in, nodata_out, xytype, routing, recursionlimit, inplace, apply_mask, ignore_metadata, **kwargs)
#     900                                       xytype=xytype, recursionlimit=recursionlimit, inplace=inplace,
#     901                                       apply_mask=apply_mask, ignore_metadata=ignore_metadata,
# --> 902                                       properties=properties, metadata=metadata, **kwargs)
#     903         elif routing.lower() == 'dinf':
#     904             return self._dinf_catchment(x, y, fdir=fdir, pour_value=pour_value, out_name=out_name,
#
# ~/.local/lib/python3.6/site-packages/pysheds/grid.py in _d8_catchment(self, x, y, fdir, pour_value, out_name, dirmap, nodata_in, nodata_out, xytype, recursionlimit, inplace, apply_mask, ignore_metadata, properties, metadata, **kwargs)
#     937             # get the flattened index of the pour point
#     938             pour_point = np.ravel_multi_index(np.array([y, x]),
# --> 939                                               fdir.shape)
#     940             # reorder direction mapping to work with select_surround_ravel()
#     941             r_dirmap = np.array(dirmap)[[4, 5, 6, 7, 0, 1, 2, 3]].tolist()
#
# <__array_function__ internals> in ravel_multi_index(*args, **kwargs)
#
# ValueError: invalid entry in coordinates array

# %%
# Clip the bounding box to the catchment
grid.clip_to('catch')

# %%
# Get a view of the catchment
catch = grid.view('catch', nodata=np.nan)

# %%
# Plot the catchment
fig, ax = plt.subplots(figsize=(8,6))
fig.patch.set_alpha(0)

plt.grid('on', zorder=0)
im = ax.imshow(catch, extent=grid.extent, zorder=1, cmap='viridis')
plt.colorbar(im, ax=ax, boundaries=boundaries, values=sorted(dirmap), label='Flow Direction')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Delineated Catchment')
plt.savefig('img/catchment.png', bbox_inches='tight')

# %%
grid.accumulation(data='catch', dirmap=dirmap, out_name='acc')

# %%
fig, ax = plt.subplots(figsize=(8,6))
fig.patch.set_alpha(0)
plt.grid('on', zorder=0)
acc_img = np.where(grid.mask, grid.acc + 1, np.nan)
im = ax.imshow(acc_img, extent=grid.extent, zorder=2,
               cmap='cubehelix',
               norm=colors.LogNorm(1, grid.acc.max()))
plt.colorbar(im, ax=ax, label='Upstream Cells')
plt.title('Flow Accumulation')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.savefig('img/flow_accumulation.png', bbox_inches='tight')

# %%
grid.flow_distance(data='catch', x=x, y=y, dirmap=dirmap, out_name='dist',
                   xytype='label', nodata_out=np.nan)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-ed76ceab342f> in <module>
#       1 grid.flow_distance(data='catch', x=x, y=y, dirmap=dirmap, out_name='dist',
# ----> 2                    xytype='label', nodata_out=np.nan)
#
# ~/.local/lib/python3.6/site-packages/pysheds/grid.py in flow_distance(self, x, y, data, weights, dirmap, nodata_in, nodata_out, out_name, routing, method, inplace, xytype, apply_mask, ignore_metadata, **kwargs)
#    1556                                           xytype=xytype, apply_mask=apply_mask,
#    1557                                           ignore_metadata=ignore_metadata,
# -> 1558                                           properties=properties, metadata=metadata, **kwargs)
#    1559         elif routing.lower() == 'dinf':
#    1560             return self._dinf_flow_distance(x, y, fdir, weights=weights, dirmap=dirmap,
#
# ~/.local/lib/python3.6/site-packages/pysheds/grid.py in _d8_flow_distance(self, x, y, fdir, weights, dirmap, nodata_in, nodata_out, out_name, method, inplace, xytype, apply_mask, ignore_metadata, properties, metadata, **kwargs)
#    1597             C = scipy.sparse.lil_matrix((fdir.size, fdir.size))
#    1598             for i,j,w in zip(startnodes, endnodes, weights):
# -> 1599                 C[i,j] = w
#    1600             C = C.tocsr()
#    1601             xyindex = np.ravel_multi_index((y, x), fdir.shape)
#
# ~/.local/lib/python3.6/site-packages/scipy/sparse/lil.py in __setitem__(self, key, x)
#     342             if x.size > 1:
#     343                 raise ValueError("Trying to assign a sequence to an item")
# --> 344             return self._set_intXint(key[0], key[1], x)
#     345         # Everything else takes the normal path.
#     346         IndexMixin.__setitem__(self, key, x)
#
# ~/.local/lib/python3.6/site-packages/scipy/sparse/lil.py in _set_intXint(self, row, col, x)
#     312     def _set_intXint(self, row, col, x):
#     313         _csparsetools.lil_insert(self.shape[0], self.shape[1], self.rows,
# --> 314                                  self.data, row, col, x)
#     315
#     316     def _set_arrayXarray(self, row, col, x):
#
# _csparsetools.pyx in scipy.sparse._csparsetools.lil_insert()
#
# _csparsetools.pyx in scipy.sparse._csparsetools.lil_insert()
#
# IndexError: column index (162) out of bounds

# %%
fig, ax = plt.subplots(figsize=(8,6))
fig.patch.set_alpha(0)
plt.grid('on', zorder=0)
im = ax.imshow(grid.dist, extent=grid.extent, zorder=2,
               cmap='cubehelix_r')
plt.colorbar(im, ax=ax, label='Distance to outlet (cells)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Flow Distance')
plt.savefig('img/flow_distance.png', bbox_inches='tight')
